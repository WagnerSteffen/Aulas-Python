# %%
import matplotlib.pyplot as plt

# Dados do IDH do Brasil e de Cuba
anos = [1960, 1965, 1970, 1975, 1980, 1985, 1990, 1995, 2000, 2005, 2010, 2015, 2020]
idh_brasil = [0.523, 0.545, 0.578, 0.611, 0.628, 0.649, 0.665, 0.688, 0.705, 0.725, 0.730, 0.754, 0.765]
idh_cuba = [0.651, 0.669, 0.718, 0.729, 0.733, 0.732, 0.726, 0.733, 0.738, 0.776, 0.780, 0.777, 0.778]

# Cria o gráfico em linha
plt.plot(anos, idh_brasil, label='Brasil')
plt.plot(anos, idh_cuba, label='Cuba')

# Configurações do gráfico
plt.title('IDH do Brasil e de Cuba ao longo do tempo')
plt.xlabel('Ano')
plt.ylabel('IDH')
plt.legend()

# Mostra o gráfico
plt.show()

# %%
import matplotlib.pyplot as plt

# Dados
anos = [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022]
gasolina = [2.72, 2.89, 2.98, 2.98, 3.11, 3.5, 3.64, 3.68, 4.34, 4.52, 4.5, 6.05, 7.28]
dolar = [1.76, 1.67, 2.04, 2.33, 2.35, 3.33, 3.48, 3.19, 3.65, 3.96, 5.2, 5.43, 5.45]
inflacao = [5.91, 6.5, 5.84, 5.91, 6.41, 10.67, 6.29, 2.95, 3.75, 4.31, 4.52, 10.67, 9.93]

# Plotagem do gráfico
plt.figure(figsize=(10, 6))
plt.plot(anos, gasolina, label='Preço Médio da Gasolina (R$/litro)')
plt.plot(anos, dolar, label='Preço Médio do Dólar (R$)')
plt.plot(anos, inflacao, label='Inflação Anual Brasileira (%)')

# Personalização do gráfico
plt.xlabel('Ano')
plt.ylabel('Valor')
plt.title('Preço Médio da Gasolina, Preço Médio do Dólar e Inflação Anual no Brasil')
plt.legend()

# Exibição do gráfico
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Dados mensais
meses = np.arange(1, 13)
anos = np.arange(2010, 2023)

gasolina = [
3.01, 3.01, 3.02, 3.03, 3.05, 3.06, 3.08, 3.10, 3.12, 3.14, 3.16, 3.18,
3.18, 3.20, 3.23, 3.25, 3.28, 3.32, 3.36, 3.40, 3.44, 3.47, 3.51, 3.55,
3.54, 3.57, 3.61, 3.64, 3.67, 3.70, 3.73, 3.76, 3.78, 3.81, 3.84, 3.87,
3.88, 3.91, 3.93, 3.95, 3.97, 4.00, 4.03, 4.06, 4.10, 4.13, 4.17, 4.20,
4.20, 4.23, 4.26, 4.30, 4.33, 4.36, 4.39, 4.42, 4.45, 4.47, 4.50, 4.53,
4.51, 4.54, 4.57, 4.59, 4.62, 4.65, 4.68, 4.70, 4.73, 4.75, 4.78, 4.81,
4.81, 4.84, 4.87, 4.89, 4.92, 4.95, 4.98, 5.00, 5.03, 5.06, 5.09, 5.12,
5.11, 5.14, 5.16, 5.18, 5.21, 5.24, 5.27, 5.30, 5.33, 5.36, 5.39, 5.42,
5.42, 5.45, 5.48, 5.51, 5.55, 5.59, 5.63, 5.67, 5.71, 5.75, 5.78, 5.82,
5.82, 5.85, 5.88, 5.91, 5.94, 5.97, 6.00, 6.03, 6.06, 6.09, 6.12, 6.14,
6.15, 6.17, 6.20, 6.23, 6.25, 6.28, 6.31, 6.34, 6.37, 6.40, 6.43, 6.46,
6.47, 6.50, 6.53, 6.56, 6.59, 6.62, 6.65, 6.68, 6.71, 6.74, 6.77, 6.80,
0.35, 0.39, 0.25, 0.31, 0.35, 0.39, 0.31, 0.36, 0.40, 0.46, 0.43, 0.44
]

datas = [f'{ano}/{mes:02}' for ano in anos for mes in meses]
# Cálculo da variação percentual do valor anual do barril de petróleo
var_combustivel = []
acumulado_comb = []
for i in range(len(gasolina)):
    if i == 0:
        var_combustivel.append(float(0))
        acumulado_comb.append(float(1))
    else:
        valor_inicial = gasolina[i-1]
        valor_final = gasolina[i]
        variacao_percentual = (valor_final - valor_inicial) / valor_inicial
        var_combustivel.append(variacao_percentual)
        acumulado = acumulado_comb[i-1] * (1 + variacao_percentual)
        acumulado_comb.append(acumulado)

#Cálculo da inflação acumulada
inflacao_acumulada = []
for i in range(len(inflacao)):
    if i == 0:
        inflacao_acumulada.append(1 + (inflacao[0]/100))
    else:
        acumulado = inflacao_acumulada[i-1] * (1 + (inflacao[i]/100))
        inflacao_acumulada.append(acumulado)

# #Plotagem do gráfico
# plt.figure(figsize=(12, 6))
# plt.plot(datas, gasolina, '-o', label='Gasolina')
# plt.plot(datas, dolar, '-o', label='Dólar')
# # plt.plot(datas, var_petroleo, '-o', label='Variação Petróleo')
# # plt.plot(datas, inflacao_acumulada, '-o', label='Inflação Acumulada')

# #Personalização do gráfico
# plt.xticks(np.arange(0, len(datas), 12), rotation=45)
# plt.xlabel('Ano')
# plt.ylabel('Valor')
# plt.title('Variação Mensal: Gasolina, Dólar, Variação Petróleo e Inflação Acumulada')
# plt.legend()

# #Exibição do gráfico
# plt.show()

# %%
for i in inflacao_acumulada:
    print(i)
# Out:
# 1.0075
# 1.01586225
# 1.023887561775
# 1.0311571634636028
# 1.0377565693097697
# 1.0439831087256284
# 1.0504558039997272
# 1.0570736755649255
# 1.0630989955156456
# 1.0693712795891879
# 1.0754666958828463
# 1.0808440293622603
# 1.086356333912008
# 1.0912449374146118
# 1.0959372906454947
# 1.1013073833696576
# 1.1064835280714949
# 1.1103562204197452
# 1.1130210753487526
# 1.1154697217145197
# 1.1181468490466346
# 1.1204949574296326
# 1.1241925907891503
# 1.131275004111122
# 1.1341031916213997
# 1.1370518599196153
# 1.141145246615326
# 1.1435416516332182
# 1.1450282557803415
# 1.1480053292453702
# 1.150071738838012
# 1.151911853620153
# 1.1546764420688411
# 1.1567548596645651
# 1.1603407997295254
# 1.163705788048741
# 1.167196905412887
# 1.1709319355102084
# 1.1733908925747798
# 1.1777324388773065
# 1.1824433686328157
# 1.1865819204230306
# 1.1894297170320458
# 1.1903812608056714
# 1.1935952902098466
# 1.2000407047769799
# 1.2060409083008647
# 1.2121917169331993
# 1.2167980454575456
# ...

# %%
for i in acumulado_comb:
    print(i)
# Out:
# 1.0
# 1.0
# 1.0033222591362128
# 1.0066445182724253
# 1.0132890365448506
# 1.0166112956810633
# 1.0232558139534886
# 1.029900332225914
# 1.036544850498339
# 1.0431893687707643
# 1.0498338870431896
# 1.0564784053156149
# 1.0564784053156149
# 1.0631229235880402
# 1.073089700996678
# 1.0797342192691033
# 1.0897009966777411
# 1.1029900332225917
# 1.116279069767442
# 1.1295681063122924
# 1.1428571428571428
# 1.1528239202657806
# 1.166112956810631
# 1.1794019933554816
# 1.176079734219269
# 1.1860465116279069
# 1.1993355481727572
# 1.2093023255813953
# 1.219269102990033
# 1.229235880398671
# 1.2392026578073088
# 1.2491694352159466
# 1.2558139534883717
# 1.2657807308970095
# 1.2757475083056473
# 1.2857142857142851
# 1.2890365448504977
# 1.2990033222591355
# 1.3056478405315608
# 1.3122923588039859
# 1.3189368770764112
# 1.328903654485049
# 1.338870431893687
# 1.3488372093023246
# 1.362126245847175
# 1.3720930232558128
# 1.3853820598006634
# 1.3953488372093013
# 1.3953488372093013
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Definindo os dados de exemplo
anos = np.arange(2010, 2023)
meses = np.arange(1, 13)
gasolina = [
3.01, 3.01, 3.02, 3.03, 3.05, 3.06, 3.08, 3.10, 3.12, 3.14, 3.16, 3.18,
3.18, 3.20, 3.23, 3.25, 3.28, 3.32, 3.36, 3.40, 3.44, 3.47, 3.51, 3.55,
3.54, 3.57, 3.61, 3.64, 3.67, 3.70, 3.73, 3.76, 3.78, 3.81, 3.84, 3.87,
3.88, 3.91, 3.93, 3.95, 3.97, 4.00, 4.03, 4.06, 4.10, 4.13, 4.17, 4.20,
4.20, 4.23, 4.26, 4.30, 4.33, 4.36, 4.39, 4.42, 4.45, 4.47, 4.50, 4.53,
4.51, 4.54, 4.57, 4.59, 4.62, 4.65, 4.68, 4.70, 4.73, 4.75, 4.78, 4.81,
4.81, 4.84, 4.87, 4.89, 4.92, 4.95, 4.98, 5.00, 5.03, 5.06, 5.09, 5.12,
5.11, 5.14, 5.16, 5.18, 5.21, 5.24, 5.27, 5.30, 5.33, 5.36, 5.39, 5.42,
5.42, 5.45, 5.48, 5.51, 5.55, 5.59, 5.63, 5.67, 5.71, 5.75, 5.78, 5.82,
5.82, 5.85, 5.88, 5.91, 5.94, 5.97, 6.00, 6.03, 6.06, 6.09, 6.12, 6.14,
6.15, 6.17, 6.20, 6.23, 6.25, 6.28, 6.31, 6.34, 6.37, 6.40, 6.43, 6.46,
6.47, 6.50, 6.53, 6.56, 6.59, 6.62, 6.65, 6.68, 6.71, 6.74, 6.77, 6.80,
6.80, 6.83, 6.86, 6.89, 6.92, 6.95, 6.98, 7.01, 7.04, 7.06, 7.09, 7.12
]
dolar = [
1.77, 1.80, 1.81, 1.79, 1.81, 1.83, 1.82, 1.77, 1.76, 1.75, 1.75, 1.74,
1.74, 1.76, 1.74, 1.71, 1.67, 1.63, 1.60, 1.61, 1.64, 1.66, 1.68, 1.67,
1.67, 1.64, 1.66, 1.66, 1.67, 1.66, 1.65, 1.63, 1.62, 1.62, 1.63, 1.62,
1.62, 1.64, 1.65, 1.64, 1.62, 1.58, 1.56, 1.57, 1.56, 1.57, 1.55, 1.55,
1.55, 1.54, 1.52, 1.53, 1.53, 1.51, 1.53, 1.52, 1.50, 1.50, 1.49, 1.47,
1.47, 1.46, 1.47, 1.49, 1.53, 1.53, 1.53, 1.56, 1.57, 1.56, 1.55, 1.57,
1.57, 1.57, 1.54, 1.55, 1.54, 1.53, 1.55, 1.58, 1.59, 1.58, 1.58, 1.56,
1.56, 1.56, 1.54, 1.55, 1.54, 1.54, 1.55, 1.55, 1.55, 1.58, 1.59, 1.61,
1.61, 1.61, 1.63, 1.64, 1.65, 1.66, 1.68, 1.68, 1.68, 1.66, 1.66, 1.66,
1.66, 1.64, 1.64, 1.63, 1.63, 1.62, 1.63, 1.61, 1.60, 1.59, 1.59, 1.61,
1.61, 1.60, 1.61, 1.59, 1.58, 1.58, 1.59, 1.60, 1.60, 1.61, 1.61, 1.61,
1.61, 1.62, 1.62, 1.62, 1.62, 1.62, 1.62, 1.62, 1.62, 1.62, 1.62, 1.62,
1.62, 1.62, 1.62, 1.62, 1.62, 1.62, 1.62, 1.62, 1.62, 1.62, 1.62, 1.62
]

# Criando uma lista de datas (ano/mês)
datas = [f'{ano}/{mes:02}' for ano in anos for mes in meses]

# Plotando o gráfico
plt.figure(figsize=(12, 6))
plt.plot(datas, gasolina, label='Gasolina')
plt.plot(datas, dolar, label='Dólar')

# Personalizando o eixo x
plt.xticks(np.arange(0, len(datas), 12), rotation=45)
plt.xlabel('Data')
plt.ylabel('Valor')
plt.title('Variação Mensal: Gasolina e Dólar')

# Exibindo o gráfico
plt.legend()
plt.tight_layout()
plt.show()

# %%
for i in datas:
    print(i)
    
for i in range(len(gasolina)):
    print(i)
# Out:
# 2010/01
# 2010/02
# 2010/03
# 2010/04
# 2010/05
# 2010/06
# 2010/07
# 2010/08
# 2010/09
# 2010/10
# 2010/11
# 2010/12
# 2011/01
# 2011/02
# 2011/03
# 2011/04
# 2011/05
# 2011/06
# 2011/07
# 2011/08
# 2011/09
# 2011/10
# 2011/11
# 2011/12
# 2012/01
# 2012/02
# 2012/03
# 2012/04
# 2012/05
# 2012/06
# 2012/07
# 2012/08
# 2012/09
# 2012/10
# 2012/11
# 2012/12
# 2013/01
# 2013/02
# 2013/03
# 2013/04
# 2013/05
# 2013/06
# 2013/07
# 2013/08
# 2013/09
# 2013/10
# 2013/11
# 2013/12
# 2014/01
# 2014/02
# 2014/03
# 2014/04
# 2014/05
# 2014/06
# 2014/07
# 2014/08
# 2014/09
# 2014/10
# 2014/11
# 2014/12
# 2015/01
# 2015/02
# 2015/03
# 2015/04
# 2015/05
# 2015/06
# 2015/07
# 2015/08
# 2015/09
# 2015/10
# 2015/11
# 2015/12
# 2016/01
# 2016/02
# 2016/03
# 2016/04
# 2016/05
# 2016/06
# 2016/07
# 2016/08
# 2016/09
# 2016/10
# 2016/11
# 2016/12
# 2017/01
# 2017/02
# 2017/03
# 2017/04
# 2017/05
# 2017/06
# 2017/07
# 2017/08
# 2017/09
# 2017/10
# 2017/11
# 2017/12
# 2018/01
# 2018/02
# 2018/03
# 2018/04
# ...
